# %%
import matplotlib.pyplot as plt

# %%
x = [3,6,27,8,1,3,5]
y = [ 8,9,2,1,3,0,1]

plt.plot(x,y)
plt.show()

# %%
# Real data

# Oscar Winner Movies
oscar_movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232] # in $M
non_oscar_revenue = [378,2788,829,185,275]
# Plot
plt.plot(years,oscar_revenue, color = "red", marker= "o"  , label = "Oscar Movies")
plt.plot(years,non_oscar_revenue, color = "green", marker = ".", linestyle = "--",linewidth = 3,label = "Non-Oscar Movies")

plt.title("oscar Moives Revenue in each Year")
plt.xlabel("years") 
plt.ylabel("Revenue in Millions Dollers")
plt.legend()
plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

sales = [120, 150, 170, 160, 190, 220,
         240, 230, 210, 250, 280, 300]

plt.plot(months,sales)
plt.title("Sales in Months")
plt.xlabel("months")
plt.ylabel("sales")



plt.show()
print(plt.style.available)
# plt.style.use("fivethirtyeight")
# plt.grid()
# plt.style.use("classic")
plt.style.use("default")
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Oscar Winner Movies
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M

plt.plot(movies,revenue)
plt.title("movies vs revenue")
plt.xlabel("movies")
plt.ylabel("revenue in million dollars")
plt.tight_layout()

plt.savefig("final.png")

# %%
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M

plt.bar(years,revenue,color = "red")
plt.title("revenue in years")
plt.xlabel("years")
plt.ylabel("revenue")
# Out:
# Text(0, 0.5, 'revenue')

# %%
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M

plt.bar(years,revenue)
plt.title("revenue in years")
plt.xlabel("years")
plt.ylabel("revenue")

for i in range(len(years)):
    plt.text(years[i],revenue[i]+15,str(revenue[i]),ha = "center")

plt.ylim(0,max(revenue)+100)
# Out:
# (0.0, 1105.0)

# %%
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M
non_oscar_revenue = [378,2788,829,185,275]

width = 0.4
import numpy as np
x = np.arange(len(years))

plt.bar(x-width/2,revenue,width, label="oscar revenue")
plt.bar(x+width/2,non_oscar_revenue,width, label= "non oscar revenue")


plt.title("revenue in years")
plt.xlabel("years")
plt.ylabel("revenue")
plt.legend()

# for i in range(len(years)):
#     plt.text(years[i],revenue[i]+15,str(revenue[i]),ha = "center")
plt.xticks(x, years) # for the showing years in the x-axis
plt.show()

# %%
movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]
# Oscar Moives 
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232] # in $M
non_oscar_revenue = [378,2788,829,185,275]

plt.barh(years,revenue)

plt.title("revenue in years")
plt.xlabel("revenue")
plt.ylabel("years")
# plt.legend()
plt.show()

# %%
# Scatter Plots

people = ["Person A", "Person B", "Person C", "Person D", "Person E",
           "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 140, 120, 122, 125, 130, 135, 123, 145, 150]

colors = [ "green" if x < 135 else "red" for x in bp]

# plt.scatter(age,bp, color = colors, s = bp, marker = ">", alpha = 0.5 )
plt.scatter(age,bp, s =bp, cmap = "OrRd" , c = bp )
plt.title("Age Vs BP")
plt.xlabel("Age")
plt.ylabel("Blood_Pressure")
plt.grid()
plt.colorbar(label= "level")

for i in range(len(people)):
    plt.annotate(people[i], xy=(age[i] , bp[i] ) ,  xytext= (age[i], bp[i] ) )
plt.ylim(min(bp) -10 , max(bp)+10)
plt.xlim(min(age) -4 , max(age)+8)
plt.show()

# %%
# Winter: Temperature (℃) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp, winter_humidity, label="Winter")
plt.scatter(summer_temp, summer_humidity, label="Summer")

plt.title("Summer vs Winter Data")
plt.xlabel("Temperature (℃)")
plt.ylabel("Humidity (%)")

plt. legend()

# %%
plt.pie(revenue,labels=movies, autopct = "%1.1f%%")


plt.show()
